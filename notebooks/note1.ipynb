// %% [markdown]
// # Pupilomeria - kajetany

// %%
%use krangl
import java.io.*

// %%
data class Study(
    val subject: String, 
    val group: Int,
    val session: Int,
    val run: Int, 
    var trials: Map<String, List<Double>>)

// %%
import java.io.*
fun readData(path: String): Unit {
    val dataFolder: File = File(path)
    dataFolder.listFiles().forEach { 
        file -> run {
            val atrs = file.getName().split("_")
                when(atrs.size) {
                    2 -> println(file.getName())
                    3 -> println(atrs.size)
                    else -> throw IllegalStateException("")
                }
            }
    }
}

// %%
readData("../resources/ET")
// Out:
// 3
// 44760927_4.txt
// 84206351_4.txt
// 67723944_1.txt
// 35213365_1.txt
// 74856862_1.txt
// 69189805_4.txt
// 39540956_4.txt
// 3
// 44760927_2.txt
// 4529209_2.txt
// 12051804_1.txt
// 15246098_1.txt
// 96148024_3.txt
// 19861910_3.txt
// 96770788_3.txt
// 3
// 3
// 52645476_4.txt
// 3
// 51827474_1.txt
// 13453690_3.txt
// 3
// 3
// 73122277_3.txt
// 3
// 62656247_4.txt
// 05126762_2.txt
// 3
// 58797805_2.txt
// 3
// 68045039_2.txt
// 3
// 3
// 01251385_3.txt
// 37760537_1.txt
// 61744545_1.txt
// 3
// 68045039_3.txt
// 3
// 3
// 3
// 25014271_1.txt
// 3
// 75524371_2.txt
// 44296699_2.txt
// 55270203_2.txt
// 62656247_3.txt
// 19861910_2.txt
// 3
// 3
// 55270203_1.txt
// 67723944_3.txt
// 18366622_3.txt
// 79234988_3.txt
// 21523076_3.txt
// 43514922_4.txt
// 54578671_3.txt
// 27616904_2.txt
// 3
// 52280506_4.txt
// 32837660_1.txt
// 3
// 3
// 96770788_1.txt
// 61422198_1.txt
// 52645476_1.txt
// 3
// 93822148_3.txt
// 44296699_4.txt
// 3
// 3
// 91218349_3.txt
// ...

// %%
val df = DataFrame.readDelim(FileReader("../resources/ET/35213365_1.txt"), CSVFormat = CSVFormat.DEFAULT.withoutHeaders, skip = 44)
df.setNames(
// Out:
// <html><body><table><tr><th style="text-align:left">10	  0.0168	  16.7898	0.3667	0.6376	0.3697	0.6345	-1	0.2762	0.2627	1	0.2503	  0.0124	  16.8645	0.3934	0.6108	0.3919	0.6089	-1	0.2763	0.2609	1	0.2171	 -1.70	 -1.30	  9.50	1	</th></tr><tr><td style="text-align:left" title="10	  0.0334	  16.5691	0.3725	0.6273	0.3708	0.6317	-1	0.2737	0.2626	1	0.2668	  0.0289	  16.5271	0.3928	0.6120	0.3923	0.6101	-1	0.2760	0.2624	1	0.2336	 -1.69	 -1.30	  9.51	2	">10	  0.0334	  16.5691	0.3725	0.6273	0.3708	0.63...</td></tr><tr><td style="text-align:left" title="10	  0.0501	  16.7683	0.3753	0.6369	0.3726	0.6337	-1	0.2746	0.2617	1	0.2836	  0.0455	  16.6214	0.3963	0.6180	0.3939	0.6133	-1	0.2758	0.2617	1	0.2502	 -1.67	 -1.32	  9.52	3	">10	  0.0501	  16.7683	0.3753	0.6369	0.3726	0.63...</td></tr><tr><td style="text-align:left" title="10	  0.0667	  16.6083	0.3701	0.6331	0.3716	0.6335	-1	0.2763	0.2621	1	0.3002	  0.0621	  16.6240	0.3950	0.6104	0.3944	0.6121	-1	0.2778	0.2648	1	0.2668	 -1.67	 -1.32	  9.49	4	">10	  
// ...

// %%
import krangl.C

// %%
val dataFolder: File = File("../resources/ET")
dataFolder.listFiles().forEach { print(it.toString() + "\n") }
// Out:
// ../resources/ET/69189805_2_1.txt
// ../resources/ET/44760927_4.txt
// ../resources/ET/84206351_4.txt
// ../resources/ET/67723944_1.txt
// ../resources/ET/35213365_1.txt
// ../resources/ET/74856862_1.txt
// ../resources/ET/69189805_4.txt
// ../resources/ET/39540956_4.txt
// ../resources/ET/47422828_2_1.txt
// ../resources/ET/44760927_2.txt
// ../resources/ET/4529209_2.txt
// ../resources/ET/12051804_1.txt
// ../resources/ET/15246098_1.txt
// ../resources/ET/96148024_3.txt
// ../resources/ET/19861910_3.txt
// ../resources/ET/96770788_3.txt
// ../resources/ET/79234988_2_2.txt
// ../resources/ET/90247624_2_2.txt
// ../resources/ET/52645476_4.txt
// ../resources/ET/40336340_2_1.txt
// ../resources/ET/51827474_1.txt
// ../resources/ET/13453690_3.txt
// ../resources/ET/69612942_2_3.txt
// ../resources/ET/90247624_2_3.txt
// ../resources/ET/73122277_3.txt
// ../resources/ET/37508289_2_3.txt
// ../resources/ET/62656247_4.txt
// ../resources/ET/05126762_2.txt
// ...
